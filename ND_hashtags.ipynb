# %%
import json
import requests
from pandas import json_normalize
import pandas as pd

# %%
#json files: 10000 tweets each data set

df_mpox_raw = pd.read_json(path_or_buf='./data/tw_hshtag_monkeypox', lines=True)
df_flu_raw = pd.read_json(path_or_buf='./data/tw_hshtag_flu', lines=True)
df_covid19_raw = pd.read_json(path_or_buf='./data/tw_hshtag_covid19', lines=True)

# %%
df_flu_raw.tail() #22.12.22
df_mpox_raw.tail()#26.10.22
df_covid19_raw.tail()#19.02.23 
 
#many tweets still about covid 19 with 10000 hashtags we can only go back 3 days
# Out:
#                                _type  \
# 9995  snscrape.modules.twitter.Tweet
# 9996  snscrape.modules.twitter.Tweet
# 9997  snscrape.modules.twitter.Tweet
# 9998  snscrape.modules.twitter.Tweet
# 9999  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 9995  https://twitter.com/contrareplicasl/status/162...
# 9996  https://twitter.com/vorkywh24/status/162738451...
# 9997  https://twitter.com/LongCovidHell/status/16273...
# 9998  https://twitter.com/Niklaslin1/status/16273844...
# 9999  https://twitter.com/RebecaPardo/status/1627383...
#
#                           date  \
# 9995 2023-02-19 19:08:09+00:00
# 9996 2023-02-19 19:07:59+00:00
# 9997 2023-02-19 19:07:57+00:00
# 9998 2023-02-19 19:07:54+00:00
# 9999 2023-02-19 19:05:02+00:00
#
#                                              rawContent  \
# 9995  A la baja casos COVID en SLP 😷📢\n\nNo se regis...
# 9996  Explanation: KRS Beijing was forced to play in...
# ...

# %%
df_flu_raw.columns
# Out:
# Index(['_type', 'url', 'date', 'rawContent', 'renderedContent', 'id', 'user',
#        'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel', 'links',
#        'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#        'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#        'cashtags', 'card', 'viewCount', 'vibe'],
#       dtype='object')

# %%
df_flu_raw.coordinates
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 9995    None
# 9996    None
# 9997    None
# 9998    None
# 9999    None
# Name: coordinates, Length: 10000, dtype: object

# %%
#ideas for data cleaning: 

#Are we affected by different languages? What do we want to measure?
